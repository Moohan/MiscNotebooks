# %%
NHSBoards1 = ('A', 'B', 'F', 'G', 'H', 'L', 'N', 'R', 'S', 'T', 'V', 'W', 'Y', 'Z')
NHSBoards2 = tuple(map(lambda x: "S080000" + str(x), (i for i in range(15, 31) if i not in (18, 27))))
NHSBoards3 = ('S08000015', 'S08000016', 'S08000017', 'S08000019', 'S08000020', 'S08000021', 'S08000022', 'S08000023', 'S08000024', 'S08000025', 'S08000026', 'S08000028', 'S08000029', 'S08000030')

# %%
print(NHSBoards1)
print(NHSBoards2)
print(NHSBoards3)
# Out:
# ('A', 'B', 'F', 'G', 'H', 'L', 'N', 'R', 'S', 'T', 'V', 'W', 'Y', 'Z')
# ('S08000015', 'S08000016', 'S08000017', 'S08000019', 'S08000020', 'S08000021', 'S08000022', 'S08000023', 'S08000024', 'S08000025', 'S08000026', 'S08000028', 'S08000029', 'S08000030')
# ('S08000015', 'S08000016', 'S08000017', 'S08000019', 'S08000020', 'S08000021', 'S08000022', 'S08000023', 'S08000024', 'S08000025', 'S08000026', 'S08000028', 'S08000029', 'S08000030')
